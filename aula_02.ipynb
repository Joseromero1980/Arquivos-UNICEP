# %% [markdown]
# # Aula 02: Estruturas de Decisão
#
# Até agora, nossos programas executaram todas as linhas de código, de cima para baixo. Mas e se a gente só quisesse executar um código se uma **condição** for verdadeira?
# Para isso usamos as estruturas de decisão, lideradas pelo comando `if` (se).

# %% [markdown]
# ## 1. O comando `if`
#
# O `if` verifica se uma afirmação é Verdadeira (`True`) ou Falsa (`False`). Se for Verdadeira, o bloco de código dentro do `if` é executado.

# %%
idade = 18

# Lê-se: Se idade for maior ou igual a 18...
if idade >= 18:
    print("Você é maior de idade.")
    print("Pode entrar na festa!")

print("Fim do programa.")
# Out:
# Você é maior de idade.
# Pode entrar na festa!
# Fim do programa.

# %%
idade = 45
# Lê-se: Se idade for maior ou igual a 45...
if idade >= 45:
  print("você se aposenta em 20 anos")
  print("alegre-se ainda poderá crescer em sua área")

  print("Fim do programa")
# Out:
# você se aposenta em 20 anos
# alegre-se ainda poderá crescer em sua área
# Fim do programa

# %%
idade = 45

if idade >= 45:
    print("Você está com um ótimo tempo de empresa, logo logo vira patrimonio. kkkk. ")
    print("Mas agora falando sério, como você vem contribuindo muito positivamente nestes ultimos anos, e sendo muito eficiciente, esta na hora de assumir um cargo de maior responsabilidade, parabéns a partir de 10 de abril de 2026, você será o mais novo gerente de manutenções! ")

print("fim do programa")
# Out:
# Você está com um ótimo tempo de empresa, logo logo vira patrimonio. kkkk.
# Mas agora falando sério, como você vem contribuindo muito positivamente nestes ultimos anos, e sendo muito eficiciente, esta na hora de assumir um cargo de maior responsabilidade, parabéns a partir de 10 de abril de 2026, você será o mais novo gerente de manutenções,
# fim do programa

# %% [markdown]
# **Atenção à indentação!** No Brasil, chamamos de "espaçamento". O Python usa espaços no começo da linha (indentação) para saber quais linhas de código pertencem ao `if`. Tudo que estiver alinhado com espaços para dentro faz parte daquele bloco.
#
# ### Operadores de Comparação:
# * `==` : Igual
# * `!=` : Diferente
# * `>`  : Maior que
# * `<`  : Menor que
# * `>=` : Maior ou igual a
# * `<=` : Menor ou igual a

# %% [markdown]
# ## 2. O comando `else` (Senão)
#
# Se a condição do `if` não for verdadeira, podemos usar o `else` para realizar outra ação.

# %%
nota = 5

if nota >= 7:
    print("Você foi Aprovado!")
else:
    print("Você foi Reprovado.")
# Out:
# Você foi Reprovado.

# %%
nota= 70

if nota >= 70:
    print("aprovado")
else:
    print("reprovado")
# Out:
# aprovado

# %% [markdown]
# ## 3. O comando `elif` (Senão Se)
#
# Às vezes, temos mais de duas situações possíveis. Por exemplo, num semáforo de trânsito, temos verde, amarelo e vermelho. Usamos o `elif` para testar várias condições em sequência.

# %%
cor = input("Digite a cor do semáforo (verde/amarelo/vermelho): ").lower()

if cor == "verde":
    print("Siga em frente!")
elif cor == "amarelo":
    print("Atenção, diminua a velocidade.")
elif cor == "vermelho":
    print("Pare!")
else:
    print("Cor inválida.")
# Out:
# Digite a cor do semáforo (verde/amarelo/vermelho): verde
# Siga em frente!

# %%
cor_temperatura = input("descubra a temperatura pela cor (azul/amarelo/vermelho): ").lower()

if cor_temperatura == "azul":
  print("atenção frio, se agasalhe!")
elif cor_temperatura == "amarelo":
  print("atenção: calor com possíbilidade de chuva, e queda na temperatura. Não esqueça seu guarda-chuva e blusa!")
elif cor_temperatura == "vermelho":
  print("hoje a temperatura varia de 28 a 33 graus. Hidrate-se bastante e use protetor sola!")
# Out:
# descubra a temperatura pela cor (azul/amarelo/vermelho): azul
# atenção frio, se agasalhe!

# %% [markdown]
# No código acima, usamos `.lower()` ao final do `input()` para converter o que o usuário digitou para letras minúsculas (assim identificamos 'Verde', 'VERDE' ou 'verde' da mesma forma).

# %% [markdown]
# ## Exercício de Fixação
# Crie um código que pergunte um número inteiro ao usuário e informe na tela se esse número é **Positivo, Negativo ou Zero**.

# %%
numero = int(input("negativo/positivo/zero:"))

# Escreva seu código de validação if/elif/else aqui

if numero < 0:
  print("negativo")
elif numero >= 1:
  print("positivo")
else:
  print("zero")
